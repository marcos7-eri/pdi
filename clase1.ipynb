# %%
import cv2
import matplotlib.pyplot as plt

img=cv2.imread('image.jpg')
plt.imshow(img)
plt.show()
# Out:
# La ejecución de celdas con 'erik_pdi26 (Python 3.10.19)' requiere el paquete ipykernel.
#
# Instale "ipykernel" en el entorno de Python.
#
# Comando: "conda install -n erik_pdi26 ipykernel --update-deps --force-reinstall"
